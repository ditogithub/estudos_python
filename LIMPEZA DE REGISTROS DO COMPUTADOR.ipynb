# %%
import pyautogui
import pyperclip
import time

pyautogui.PAUSE = 1

pyautogui.click(x=20, y=744)
time.sleep(3)
pyperclip.copy("executar")
time.sleep(3)
pyautogui.hotkey("ctrl","v")
time.sleep(3)
pyautogui.press("enter")
time.sleep(3)
pyperclip.copy("prefetch")
time.sleep(3)
pyautogui.hotkey("ctrl","v")
time.sleep(3)
pyautogui.hotkey("enter")
time.sleep(5)
pyautogui.press("enter") # dar "enter" para ter acesso permanente a esta pasta.
time.sleep(3)
pyautogui.click(x=1158, y=54)  # clicar em Maximizar
time.sleep(3)
pyautogui.click(x=1181, y=93) # maximizar a tela
time.sleep(3)
pyautogui.hotkey("ctrl","a") # seleciona os arquivos
time.sleep(3)
pyautogui.press("delete") # aperta o botão delete
time.sleep(3)
pyautogui.hotkey("Alt", "f4")
time.sleep(3)
pyautogui.hotkey("Alt", "f4")

time.sleep(3)

pyautogui.click(x=159, y=750) # clicar na barra de pesquisa.
time.sleep(3)
pyperclip.copy("executar") # Copiar o nome executar na barra de pesquisa.
time.sleep(3)
pyautogui.hotkey("ctrl","v")# Colar o nome executar na barra de pesquisa.
time.sleep(3)
pyautogui.press("enter")
time.sleep(3)
pyperclip.copy("%temp%")
time.sleep(3)
pyautogui.hotkey("ctrl","v")
time.sleep(3)
pyautogui.hotkey("enter")
time.sleep(3)
pyautogui.click(x=1181, y=93) # maximizar a tela
time.sleep(3)
pyautogui.hotkey("ctrl","a") # seleciona os arquivos
time.sleep(3)
pyautogui.press("delete") # aperta o botão delete
time.sleep(3)
pyautogui.click(x=728, y=272) # clicar no botão ignorar 01
time.sleep(3)
pyautogui.click(x=492, y=289) # Clicar na caixa de seleção 01
time.sleep(3)
pyautogui.click(x=731, y=318) # clicar no botão ignorar 02
time.sleep(3)
pyautogui.hotkey("alt","f4")

time.sleep(3)

pyautogui.click(x=20, y=744)
time.sleep(3)
pyperclip.copy("executar")
time.sleep(3)
pyautogui.hotkey("ctrl","v")
time.sleep(3)
pyautogui.press("enter")
time.sleep(3)
pyperclip.copy("recent")
time.sleep(3)
pyautogui.hotkey("ctrl","v")
time.sleep(3)
pyautogui.hotkey("enter")
time.sleep(3)
pyautogui.click(x=1181, y=93) # maximizar a tela
time.sleep(3)
pyautogui.hotkey("ctrl","a") # seleciona os arquivos
time.sleep(3)
pyautogui.press("delete") # aperta o botão delete
time.sleep(3)
pyautogui.hotkey("alt","f4")

time.sleep(3)

pyautogui.click(x=20, y=744)
time.sleep(3)
pyperclip.copy("executar")
time.sleep(3)
pyautogui.hotkey("ctrl","v")
time.sleep(3)
pyautogui.press("enter")
time.sleep(3)
pyperclip.copy("temp")
time.sleep(3)
pyautogui.hotkey("ctrl","v")
time.sleep(3)
pyautogui.hotkey("enter") # Apertar na tecla Enter
time.sleep(3)
pyautogui.click(x=1157, y=53) # clicar em Maximizar
time.sleep(3)
pyautogui.hotkey("ctrl","a") # Selecionar os arquivos
time.sleep(3)
pyautogui.press("delete")
time.sleep(3)
pyautogui.mouseDown(x=685, y=118) # Clicar e arrastar a janelinha para baixo no centro inferior da tela.
time.sleep(3)
pyautogui.click(x=691, y=500)
time.sleep(3)
pyautogui.click(x=737, y=655) # Clicar em ignorar
time.sleep(3)
pyautogui.click(x=508, y=669) # Clicar na caixa de seleção: "Fazer isso para todos os itens".
time.sleep(3)
pyautogui.click(x=734, y=701) # Clicar novamente no botão "ignorar".
time.sleep(3)
pyautogui.hotkey("Alt", "f4")

time.sleep(3)

pyautogui.click(x=20, y=744)
time.sleep(3)
pyautogui.write("Lixeira")
time.sleep(3)
pyautogui.hotkey("tab")
time.sleep(3)
pyautogui.hotkey("tab")
time.sleep(3)
pyautogui.press("enter") # clicar no botão enter
time.sleep(3)
pyautogui.click(x=1182, y=89) # maximizar a telatemp
time.sleep(3)
pyautogui.hotkey("ctrl","a") # seleciona os arquivos executar
time.sleep(3)
pyautogui.press("delete") # aperta o botão delete
time.sleep(3)
pyautogui.press("enter")
time.sleep(3)
pyautogui.click(x=1332, y=8) # Fechar Janela da lixeira.


time.sleep(3)

# %%
import pyautogui
import time
time.sleep(7)
pyautogui.position()
# Out:
# Point(x=731, y=318)
