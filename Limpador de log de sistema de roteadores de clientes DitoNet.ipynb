# %% [markdown]
# O objetivo dessa automação é entrar de forma automática nos roteadores dos clientes DitoNet de forma remota, para realizar a limpesa dos logs de registros do sistema.
#
# ips: 100.64.0.6:8080 - 100.64.0.19:8080 - 100.64.0.14:8080 - 100.64.0.4:8080

# %%
import pyautogui
import pyperclip
import time

pyautogui.PAUSE = 1

# ROTEADOR DE PARAIBA.

pyautogui.hotkey("ctrl","t")
pyperclip.copy("100.64.0.6:8080")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
time.sleep(7)
pyautogui.write("admin")
time.sleep(5)
pyautogui.press("tab")
pyautogui.write("84012379182427")
pyautogui.press("enter")
time.sleep(12)
pyautogui.click(x=96, y=620) # CLICA EM FERRAMENTAS DE SISTEMA
time.sleep(5)  # TEMPO DE ESPERA
pyautogui.click(x=275, y=718,clicks=4) # CLICA NA PARTE INFERIOR DA BARRA DE ROLAGEM DE MENU
time.sleep(5) # TEMPO DE ESPERA PARA CARREGAMENTO DA PÁGINA
pyautogui.click(x=75, y=646) # CLICAR NO MENU "LOG DE SISTEMA"
pyautogui.press("tab")
pyautogui.press("tab")
pyautogui.press("tab")
pyautogui.press("tab")
pyautogui.press("tab")
pyautogui.press("tab")
time.sleep(2)
pyautogui.press("enter")
pyautogui.hotkey("ctrl","w") # fecha a aba do navegador.

    # ROTEADOR DE SEU ROBERTO ENQUANTO IGARASSU.
    
pyautogui.hotkey("ctrl","t")
pyperclip.copy("100.64.0.18:8080")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
time.sleep(4)
pyautogui.write("admin")
time.sleep(4)
pyautogui.press("tab")
time.sleep(4)
pyautogui.write("admin")
time.sleep(3)
pyautogui.press("enter")
time.sleep(6)
pyautogui.click(x=48, y=606) # CLICAR NO MENU "SISTEMA"
time.sleep(3)
pyautogui.press("tab")
pyautogui.press("tab")
pyautogui.press("tab")
pyautogui.press("tab")
pyautogui.press("tab") # CLICAR EM TAB 9 VEZES PARA CHEGAR ATÉ O MENU : LOG DE SISTEMA
pyautogui.press("tab")
pyautogui.press("tab")
pyautogui.press("tab")
pyautogui.press("tab")
pyautogui.press("enter") # DAR UM ENTER PARA ENTRAR NO MENU LOG DE SISTEMA.
pyautogui.press("tab")
pyautogui.press("tab")
pyautogui.press("tab")# CLICAR EM TAB 6 VEZES PARA CHEGAR ATÉ O BOTÃO : LIMPAR LOG
pyautogui.press("tab")
pyautogui.press("tab")
pyautogui.press("tab")
pyautogui.press("enter") # ENTER PARA LIMPAR O LOG DO SISTEMA
pyautogui.press("enter") # ENTER PARA DAR OK DE CONFIRMAÇÃO
pyautogui.hotkey("ctrl","w") # fecha a aba do navegador.


    # ROTEADOR DE SEU BIER
    
pyautogui.hotkey("ctrl","t")
pyperclip.copy("100.64.0.14:8080")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
time.sleep(4)
pyautogui.write("admin")
time.sleep(4)
pyautogui.press("tab")
time.sleep(4)
pyautogui.write("admin")
time.sleep(3)
pyautogui.press("enter")
time.sleep(8)
pyautogui.press("enter")
time.sleep(6)
pyautogui.click(x=89, y=593) # CLICAR NO MENU FERRAMENTAS DE SISTEMA.
time.sleep(4)
pyautogui.click(x=216, y=716) # CLICA 4 VEZES NA SETA INFERIOR DA BARRA DE ROLAGEM DE MENU
time.sleep(3)
pyautogui.click(x=69, y=647) # CLICA NO MENU LOG DE SISTEMA.
pyautogui.press("tab")
pyautogui.press("tab")
pyautogui.press("tab")# CLICAR EM TAB 6 VEZES PARA CHEGAR ATÉ O BOTÃO : LIMPAR LOG
pyautogui.press("tab")
pyautogui.press("tab")
pyautogui.press("tab")
time.sleep(2)
pyautogui.press("enter") # DA ENTER PARA APERTAR BOTÃO LIMPAR LOG.
pyautogui.hotkey("ctrl","w") # fecha a aba do navegador.

        # ROTEADOR DE MARQUINHO TIA FÁ
    
pyautogui.hotkey("ctrl","t")
pyperclip.copy("100.64.0.4:8080")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
time.sleep(4)
pyautogui.write("84012379182427")
time.sleep(4)
pyautogui.press("enter")
time.sleep(3)
pyautogui.click(x=1197, y=334) # clicar em não salvar a senha.
time.sleep(3)
pyautogui.click(x=1123, y=143) # clicar no menu avandado
time.sleep(3)
pyautogui.click(x=206, y=638) # clicar no menu ferramentas de sistema
time.sleep(3)
pyautogui.click(x=192, y=662) # clicar no menu log de sistema.
time.sleep(3)
pyautogui.click(x=1350, y=717,clicks=17) # clicar na seta do lado direito da barra de rolagem
time.sleep(2)
pyautogui.click(x=953, y=558) # clicar no botão limpar todos os logs
time.sleep(3)
pyautogui.click(x=814, y=435) # clicar em ok para confirmar.
time.sleep(3)
pyautogui.hotkey("ctrl","w") # fecha a aba do navegador.



     # ROTEADOR DE THIAGO LELÉ
    
pyautogui.hotkey("ctrl","t")
pyperclip.copy("100.64.0.39:8080")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
time.sleep(13)
pyautogui.click(x=577, y=353) # clicar no campo "digite a senha"
time.sleep(4)
pyautogui.write("84012379182427")
time.sleep(4)
pyautogui.press("enter")
time.sleep(13)
pyautogui.click(x=987, y=258) # clicar no botão "nunca" da janela de salvar senha
time.sleep(3)
pyautogui.click(x=920, y=202)# clicar no menu "avançado"
time.sleep(4)
pyautogui.click(x=330, y=718) # clicar na barra rolagen de menu parte inferior
time.sleep(4)
pyautogui.click(x=212, y=677) # clicar no menu "Sistema" do lado esquerdo
time.sleep(4)
pyautogui.click(x=331, y=715) # clicar na barra rolagen de menu parte inferior
time.sleep(4)
pyautogui.click(x=241, y=514) # clicar no menu "log de sistema".
time.sleep(4)
pyautogui.click(x=1054, y=454) # clicar no botão "limpar Tudo"
time.sleep(4)
pyautogui.click(x=936, y=442) # clicar no botão "sim" dando permissão para apagar os logs.
pyautogui.hotkey("ctrl","w") # fecha aba do navegador


            # ROTEADOR DE EDSON PIZZARIA
    
pyautogui.hotkey("ctrl","t")   # Abre nova aba no navegador
pyperclip.copy("100.64.0.29:8080")
pyautogui.hotkey("ctrl","v")
time.sleep(4)
pyautogui.press("enter")
time.sleep(6)
pyautogui.write("admin") # escrever nome de usuário!
time.sleep(6)
pyautogui.press("tab") # apertar tab para passar para proxima etapa!
time.sleep(4)
pyautogui.write("84012379182427") # digitar a senha de acesso do roteador do usuário!
time.sleep(3)
pyautogui.press("enter") # dar uma enter para acessar o roteador!
time.sleep(4)
pyautogui.click(x=84, y=564) # clicar em "Ferramentas de Sistemas"!
time.sleep(4)
pyautogui.click(x=172, y=700,clicks=3) # Clicar na parte inferior da seta da barra de rolagem!  
time.sleep(3)
pyautogui.click(x=61, y=660) # Clicar no menu "Histórico"!
time.sleep(3)
pyautogui.click(x=918, y=720,clicks=16) # Clicar na parte inferior da seta da barra de rolagem lado direito da tela!
time.sleep(4)
pyautogui.click(x=614, y=624) # Clicar no botão limpar !
time.sleep(4)
pyautogui.press("enter")
time.sleep(3)
pyautogui.hotkey("ctrl","w") # Fechar a aba do navegador!

# %%
import time
import pyautogui
time.sleep(7)
pyautogui.position()
# Out:
# Point(x=614, y=624)
